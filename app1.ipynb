# %% [markdown]
# ## Basic cleaning and converting to csv file

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\prade\OneDrive\Desktop\stackover flow\stackoverflow.csv")
df
# Out:
#         Unnamed: 0                                           question  \
# 0                0  qemu/kvm balloon device allocated guest physic...
# 1                1  How to Initialise List in class diagram Papyru...
# 2                2  React Vite app deployed via Docker on Azure We...
# 3                3                Preprocessing function never called
# 4                4  Making a derived class variable accessible wit...
# ...            ...                                                ...
# 105437      105445                  Cannot load Plot package in Julia
# 105438      105446  multiple update images not showing in request ...
# 105439      105447  Parse and filter json output in Ansible via js...
# 105440      105448  How to make an ArrayList stay at the initial c...
# 105441      105449    python urllib.request http error 403: forbidden
#
#                                                      text  \
# 0       I'm running a VM using qemu/kvm system virtual...
# 1       Eclipse Papyrus Class Diagram\nAnyone know how...
# 2       I'm new to deployment and currently trying to ...
# 3       I'm very new Drupal Developer, and I would lik...
# 4       are there any possibilities making _foo access...
# ...                                                   ...
# 105437  I am using Julia on a Mac laptop. Everything w...
# 105438  I'm doing multiple upload images using dropzon...
# 105439  I have the below output that I'm trying to par...
# 105440  How do I make an ArrayList not exceed a size o...
# 105441  import urllib.request\nurl = "https://wallpape...
#
#                                                      tags
# 0       memory-management,dynamic-memory-allocation,qe...
# 1                      java,eclipse,class-diagram,papyrus
# 2       reactjs,docker,azure-web-app-service,vite,azur...
# 3                                              php,drupal
# 4                                                     tcl
# ...                                                   ...
# 105437                                              julia
# 105438          javascript,php,jquery,laravel,dropzone.js
# 105439                   json,ansible,jmespath,json-query
# 105440                     java,arraylist,data-structures
# 105441                                      python,urllib
#
# [105442 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'question', 'text', 'tags'], dtype='object')

# %%
df.drop(columns="Unnamed: 0",axis = 1,inplace=True)

# %%
df
# Out:
#                                                  question  \
# 0       qemu/kvm balloon device allocated guest physic...
# 1       How to Initialise List in class diagram Papyru...
# 2       React Vite app deployed via Docker on Azure We...
# 3                     Preprocessing function never called
# 4       Making a derived class variable accessible wit...
# ...                                                   ...
# 105437                  Cannot load Plot package in Julia
# 105438  multiple update images not showing in request ...
# 105439  Parse and filter json output in Ansible via js...
# 105440  How to make an ArrayList stay at the initial c...
# 105441    python urllib.request http error 403: forbidden
#
#                                                      text  \
# 0       I'm running a VM using qemu/kvm system virtual...
# 1       Eclipse Papyrus Class Diagram\nAnyone know how...
# 2       I'm new to deployment and currently trying to ...
# 3       I'm very new Drupal Developer, and I would lik...
# 4       are there any possibilities making _foo access...
# ...                                                   ...
# 105437  I am using Julia on a Mac laptop. Everything w...
# 105438  I'm doing multiple upload images using dropzon...
# 105439  I have the below output that I'm trying to par...
# 105440  How do I make an ArrayList not exceed a size o...
# 105441  import urllib.request\nurl = "https://wallpape...
#
#                                                      tags
# 0       memory-management,dynamic-memory-allocation,qe...
# 1                      java,eclipse,class-diagram,papyrus
# 2       reactjs,docker,azure-web-app-service,vite,azur...
# 3                                              php,drupal
# 4                                                     tcl
# ...                                                   ...
# 105437                                              julia
# 105438          javascript,php,jquery,laravel,dropzone.js
# 105439                   json,ansible,jmespath,json-query
# 105440                     java,arraylist,data-structures
# 105441                                      python,urllib
#
# [105442 rows x 3 columns]

# %%
import autocorrect
import emoji
import contractions
from unidecode import unidecode
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

chat = {
    "brb": "be right back",
    "btw": "by the way",
    "lol": "laugh out loud",
    "omg": "oh my god",
    "ttyl": "talk to you later",
    "idk": "I don't know",
    "imo": "in my opinion",
    "imho": "in my humble opinion",
    "fyi": "for your information",
    "smh": "shaking my head",
    "np": "no problem",
    "tbh": "to be honest",
    "wbu": "what about you",
    "bc": "because",
    "afaik": "as far as I know",
    "asap": "as soon as possible",
    "atm": "at the moment",
    "bbl": "be back later",
    "bfn": "bye for now",
    "bff": "best friends forever",
    "cu": "see you",
    "cya": "see you",
    "dm": "direct message",
    "fb": "Facebook",
    "ftw": "for the win",
    "gg": "good game",
    "gr8": "great",
    "gtg": "got to go",
    "hbu": "how about you",
    "i'll":'i will',
    "ily": "I love you",
    "jk": "just kidding",
    "lmao": "laughing my ass off",
    "lmk": "let me know",
    "nvm": "never mind",
    "omw": "on my way",
    "pls": "please",
    "ppl": "people",
    "rofl": "rolling on the floor laughing",
    "thx": "thanks",
    "u": "you",
    "ur": "your",
    "yolo": "you only live once",
    "yw": "you're welcome",
    "ty": "thank you",
    "abt": "about"
}
def Cleaning(text): 
    text = text.lower() #1. lower
    ob = autocorrect.Speller() #2. autocorrect
    text = ob(text) #3. emojis
    text = emoji.demojize(text).replace(':',"") 
    text= contractions.fix(text) #4. contractions
    text= unidecode(text) #5. unicoding-- engilish accents
    res = []
    for i in text.split():
        if i in chat.keys():
            res.append(chat[i])
        else:
            res.append(i)   #6. chatwords cleaning
    text = " ".join(res) 
    text = re.sub("<.*?>","",text) #7.html tags
    text= re.sub(r'https\S+', '', text) #8.urls cleaning
    text= re.sub(r'[a-zA-Z0-9.%+-]+@[a-zA-Z0-9.-]+.[a-zA-Z]{2,}', '', text) #9.gmail cleaning
    text = re.sub(r"[^a-z A-Z ]","",text) #10. remove punctuations and digits
    # advanced cleaning
    preprocess = []
    for word in text.split():
        if word not in stopwords.words('english'):
            preprocess.append(word)

    text= ' '.join(preprocess)
    text= word_tokenize(text) 
    lemma  = WordNetLemmatizer()
    res=[]
    for i in text:
        res.append(lemma.lemmatize(i))
    text= ' '.join(res)
    return text

# %%
df["question"] = df["question"].apply(Cleaning)

# %%
df["text"] = df["text"].apply(Cleaning)

# %%
df
# Out:
#                                                  question  \
# 0       emukm balloon device allocated guest physical ...
# 1           initialism list class diagram papyrus eclipse
# 2       react site app deployed via decker azure web a...
# 3                     preprocessing function never called
# 4       making derived class variable accessible witho...
# ...                                                   ...
# 105437                    can not load plot package julia
# 105438       multiple update image showing request travel
# 105439       parse filter son output visible via sonquery
# 105440     make arraylist stay initial capacity duplicate
# 105441          python urllibrequest http error forbidden
#
#                                                      text  \
# 0       running vm using emukm system virtualization e...
# 1       eclipse papyrus class diagram anyone know init...
# 2       new deployment currently trying deploy reactsi...
# 3       new drupal developer would like know preproces...
# 4       possibility making foo accessible class c with...
# ...                                                   ...
# 105437  using julia mac laptop everything worked fine ...
# 105438  multiple upload image using dropzonejs main re...
# 105439  output trying parse filter name lvs debug mess...
# 105440  make arraylist exceed size shown arraylist lis...
# 105441  import urllibrequest url try urllibrequestreop...
#
#                                                      tags
# 0       memory-management,dynamic-memory-allocation,qe...
# 1                      java,eclipse,class-diagram,papyrus
# 2       reactjs,docker,azure-web-app-service,vite,azur...
# 3                                              php,drupal
# 4                                                     tcl
# ...                                                   ...
# 105437                                              julia
# 105438          javascript,php,jquery,laravel,dropzone.js
# 105439                   json,ansible,jmespath,json-query
# 105440                     java,arraylist,data-structures
# 105441                                      python,urllib
#
# [105442 rows x 3 columns]

# %%
df.to_csv(r"C:\Users\prade\OneDrive\Desktop\cleaned_stackoverflow.csv")
