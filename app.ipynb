# %% [markdown]
# # web scrapping

# %%
import pandas as pd

# %%
import requests
import re
from bs4 import BeautifulSoup
import numpy as np

# %%
url = "https://stackoverflow.com/questions?tab=newest&pagesize=50"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
page = requests.get(url,headers = headers)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text)
soup
# Out:
# <!DOCTYPE html>
# <html class="html__responsive" lang="en">
# <head>
# <title>Newest Questions - Stack Overflow</title>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" rel="shortcut icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="image_src"/>
# <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="website" property="og:type"/>
# <meta content="https://stackoverflow.com/questions?tab=newest&amp;pagesize=50" property="og:url"/>
# <meta content="Stack Overflow" property="og:site_name"/>
# ...

# %%
question = []
for i in soup.find_all("h3", class_="s-post-summary--content-title"):
    question.append(i.text.strip())  
question
# Out:
# ['qemu/kvm balloon device allocated guest physical memory (GPA)',
#  'How to Initialise List in class diagram Papyrus eclipse?',
#  'React Vite app deployed via Docker on Azure Web App shows error on base URL but works on subroutes',
#  'Preprocessing function never called',
#  'Making a derived class variable accessible without "my variable ..."',
#  'Is there a way to get the list of only visible and painted widgets of an application? Widget Tree',
#  'Howto uncompress Oracle BLOB in R',
#  'Qt 6.9.0 Android - ExpandedClientAreaHint understanding and troubles',
#  'Issues in recording video by GPUImage',
#  'Node Memory SReclaimable Bytes Equivalent on FreeBSD',
#  'Start Notepad.exe or Calc.exe with CreateRestrictedToken',
#  'Expo EAS Build: Bitcode in AgoraRtmKit.framework breaks App Store submission (SDK 52 / React Native 0.76 / Managed Workflow)',
#  'If statement with boolean causes function to stop working',
# ...

# %%
text = []
for i  in soup.find_all("div",class_ = "s-post-summary--content-excerpt"):
    text.append(i.text.strip())
text
# Out:
# ["I'm running a VM using qemu/kvm system virtualization (qemu-system-x86_64). The qemu VM is configured with a balloon device:\nroot@eve-ng62:/opt/unetlab# ps -ef | grep virtio-balloon-pci\n<snip>......",
#  'Eclipse Papyrus Class Diagram\nAnyone know how do I initalise as a list to my attribute carList?\nprivate List carList = new ArrayList<>();',
#  "I'm new to deployment and currently trying to deploy my React-Vite app using a Docker image on Azure Web App. After deployment, when I visit the base URL, the app doesn't render anything and shows ...",
#  "I'm very new Drupal Developer, and I would like to know why some of my preprocess function are never called.\nAt the beginning, I only used one single preprocess function.\n// Before\nfunction ...",
#  "are there any possibilities making _foo accessible in class C without having to write my variable _foo?\nCaveat: I don't want to make all variables (e.g. _bee) visible, only some specific variables ...",
# ...

# %%
tags = []
for i in soup.find_all("ul",class_ = "ml0 list-ls-none js-post-tag-list-wrapper d-inline"):
    tags.append(",".join(x.text for x in i))
tags
len(tags)
# Out:
# 50

# %%
question = []
text = []
tags = []
for i in range(1,4010):
    url = f"https://stackoverflow.com/questions?tab=newest&page={i}"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    for post in soup.find_all("div", class_="s-post-summary"):  # Adjust container class if needed
        # Extract question title (or np.nan if missing)
        title = post.find("h3", class_="s-post-summary--content-title")
        question.append(title.text.strip() if title else np.nan)

        # Extract text excerpt (or np.nan if missing)
        excerpt = post.find("div", class_="s-post-summary--content-excerpt")
        text.append(excerpt.text.strip() if excerpt else np.nan)

        # Extract tags (or np.nan if missing)
        tag_list = post.find("ul", class_="ml0 list-ls-none js-post-tag-list-wrapper d-inline")
        if tag_list:
            tags.append(",".join(tag.text for tag in tag_list.find_all("li")))
        else:
            tags.append(np.nan)

# %%
len(tags)
# Out:
# 25450

# %%
question1 = []
text1 = []
tags1 = []
for i in range(4010,9000):
    url = f"https://stackoverflow.com/questions?tab=newest&page={i}"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    for post in soup.find_all("div", class_="s-post-summary"):  # Adjust container class if needed
        # Extract question title (or np.nan if missing)
        title = post.find("h3", class_="s-post-summary--content-title")
        question1.append(title.text.strip() if title else np.nan)

        # Extract text excerpt (or np.nan if missing)
        excerpt = post.find("div", class_="s-post-summary--content-excerpt")
        text1.append(excerpt.text.strip() if excerpt else np.nan)

        # Extract tags (or np.nan if missing)
        tag_list = post.find("ul", class_="ml0 list-ls-none js-post-tag-list-wrapper d-inline")
        if tag_list:
            tags1.append(",".join(tag.text for tag in tag_list.find_all("li")))
        else:
            tags1.append(np.nan)

# %%
len(question1)
# Out:
# 24500

# %%
question2 = []
text2 = []
tags2 = []
for i in range(9001,15000):
    url = f"https://stackoverflow.com/questions?tab=newest&page={i}"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    for post in soup.find_all("div", class_="s-post-summary"):  # Adjust container class if needed
        # Extract question title (or np.nan if missing)
        title = post.find("h3", class_="s-post-summary--content-title")
        question2.append(title.text.strip() if title else np.nan)

        # Extract text excerpt (or np.nan if missing)
        excerpt = post.find("div", class_="s-post-summary--content-excerpt")
        text2.append(excerpt.text.strip() if excerpt else np.nan)

        # Extract tags (or np.nan if missing)
        tag_list = post.find("ul", class_="ml0 list-ls-none js-post-tag-list-wrapper d-inline")
        if tag_list:
            tags2.append(",".join(tag.text for tag in tag_list.find_all("li")))
        else:
            tags2.append(np.nan)

# %%
len(question2)
# Out:
# 29900

# %%
question3 = []
text3 = []
tags3 = []
for i in range(15001,20000):
    url = f"https://stackoverflow.com/questions?tab=newest&page={i}"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    for post in soup.find_all("div", class_="s-post-summary"):  # Adjust container class if needed
        # Extract question title (or np.nan if missing)
        title = post.find("h3", class_="s-post-summary--content-title")
        question3.append(title.text.strip() if title else np.nan)

        # Extract text excerpt (or np.nan if missing)
        excerpt = post.find("div", class_="s-post-summary--content-excerpt")
        text3.append(excerpt.text.strip() if excerpt else np.nan)

        # Extract tags (or np.nan if missing)
        tag_list = post.find("ul", class_="ml0 list-ls-none js-post-tag-list-wrapper d-inline")
        if tag_list:
            tags3.append(",".join(tag.text for tag in tag_list.find_all("li")))
        else:
            tags3.append(np.nan)

# %%
len(question3)
len(tags3)
# Out:
# 25600

# %%
csv1 = pd.DataFrame({"question":question,"text":text,"tags":tags})
csv1
# Out:
#                                                 question  \
# 0      qemu/kvm balloon device allocated guest physic...
# 1      How to Initialise List in class diagram Papyru...
# 2      React Vite app deployed via Docker on Azure We...
# 3                    Preprocessing function never called
# 4      Making a derived class variable accessible wit...
# ...                                                  ...
# 25445  White line showing above the window after usin...
# 25446  VBA to paste in to PPT as embedded table from ...
# 25447  Replacing a multi character pattern that inclu...
# 25448  How to Pass Custom Parameters from SendGrid Em...
# 25449   ERROR ~ No such variable: input_file in Nextflow
#
#                                                     text  \
# 0      I'm running a VM using qemu/kvm system virtual...
# 1      Eclipse Papyrus Class Diagram\nAnyone know how...
# 2      I'm new to deployment and currently trying to ...
# ...

# %%
csv2 = pd.DataFrame({"question":question1,"text":text1,"tags":tags1})
csv2
# Out:
#                                                 question  \
# 0      I have this error League\OAuth2\Client\Provide...
# 1      In Kotlin how i change a button color during a...
# 2      Unable to install any Ruby version using any R...
# 3      What Woocommerce's Hook should I use for disab...
# 4      WebdriverIO: Error: "Snapshot service is not i...
# ...                                                  ...
# 24495                    Swift on macOS: quit other apps
# 24496                  Fail to restore conda environment
# 24497     PHP mySQL multi-level query/report [duplicate]
# 24498  Problem with turning off barcode scanning when...
# 24499                               Delete Nth from last
#
#                                                     text  \
# 0      the program is work well for years and now thi...
# 1      I'm using Android Studio and I need a button t...
# 2      I've been trying to install Ruby using any ver...
# ...

# %%
csv3 = pd.DataFrame({"question":question2,"text":text2,"tags":tags2})
csv3
# Out:
#                                                 question  \
# 0      ActiveMQ Artemis server produces lots of AMQ22...
# 1           dt_fill raises recycle error all of a sudden
# 2       PowerShell Cmdlet "Protect-PGP" Object Not Found
# 3                   Integrate LiveChat button with Nuxt3
# 4      Publishing a Var from Another @ObservableObjec...
# ...                                                  ...
# 29895  How to add documents t0 list index content in ...
# 29896                  how do I generate dns wire format
# 29897  Is it any way to calling SvelteKit form action...
# 29898  How do I properly code this so that I don't ge...
# 29899        How to manually build a nanobind extension?
#
#                                                     text  \
# 0      I encountered a problem using Artemis ActiveMQ...
# 1      I have data wrangling script, where I just wan...
# 2      I have a Powershell script that will encrypt f...
# ...

# %%
csv4 = pd.DataFrame({"question":question3,"text":text3,"tags":tags3})
csv4
# Out:
#                                                 question  \
# 0      Safe way to terminate an endlessly looping gor...
# 1      Only blue geometries shown for protobuf vector...
# 2      How to declare a function in a function parame...
# 3                     Pass variables in %run Databricks?
# 4      Hibernate uses @JoinColumn as sequence name in...
# ...                                                  ...
# 25595                  Cannot load Plot package in Julia
# 25596  multiple update images not showing in request ...
# 25597  Parse and filter json output in Ansible via js...
# 25598  How to make an ArrayList stay at the initial c...
# 25599    python urllib.request http error 403: forbidden
#
#                                                     text  \
# 0      I have a goroutine that is acting as a listene...
# 1      I'm trying to use my vector tile server with L...
# 2      When creating a login page in a mobile applica...
# ...

# %%
df = pd.concat([csv1,csv2,csv3,csv4],ignore_index=True)
df
# Out:
#                                                  question  \
# 0       qemu/kvm balloon device allocated guest physic...
# 1       How to Initialise List in class diagram Papyru...
# 2       React Vite app deployed via Docker on Azure We...
# 3                     Preprocessing function never called
# 4       Making a derived class variable accessible wit...
# ...                                                   ...
# 105445                  Cannot load Plot package in Julia
# 105446  multiple update images not showing in request ...
# 105447  Parse and filter json output in Ansible via js...
# 105448  How to make an ArrayList stay at the initial c...
# 105449    python urllib.request http error 403: forbidden
#
#                                                      text  \
# 0       I'm running a VM using qemu/kvm system virtual...
# 1       Eclipse Papyrus Class Diagram\nAnyone know how...
# 2       I'm new to deployment and currently trying to ...
# ...

# %%
df.isnull().sum()
# Out:
# question    0
# text        0
# tags        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 8

# %%
df = df.drop_duplicates()

# %%
df["tags"].nunique()
# Out:
# 77772

# %%
df.to_csv(r"C:\Users\prade\OneDrive\Desktop\stackoverflow.csv")
